# %%
from multi_quasar_sphere_plotter import MultiQuasarSpherePlotter,sort_ions
import numpy as np
mq = None

# %%
if not mq:
    mq = MultiQuasarSpherePlotter()
else:
    mq.reset_current_Quasar_Array()
mq.constrain_current_Quasar_Array("version","v2.0",exploration_mode = False)
mq.constrain_current_Quasar_Array("redshift",[0.9,1.6],exploration_mode=False)
# Out:
# All textfiles loaded!
# Mass for VELA01z4.0 is not valid.
# Mass for VELA01z3.0 is not valid.
# Mass for VELA01z2.0 is not valid.

# %%
labels, toplot = mq.sort_by("sfr",10.0**np.arange(-1,3),exploration_mode = False)

# %%
mq.ploterr_one_galaxy_param("O VI",toplot,xVar = "rdivR>0",labels = labels,save = True)
# Out:
# Current constraints (name): versionv2.0redshift0.9-1.6

# %%
allions = list(mq.currentQuasarArray[0].ions)

currentions = sort_ions(allions,flat = False)
print currentions

for lst in currentions:
    if len(lst) > 2:
        mq.ploterr_zero_galaxy_param(lst,xVar = "rdivR>0")
# Out:
# [['C III'], ['H I'], ['Mg II', 'Mg X'], ['N II', 'N III', 'N IV', 'N V'], ['Ne VIII'], ['O II', 'O III', 'O IV', 'O V', 'O VI'], ['S II', 'S III', 'S IV', 'S V', 'S VI']]
# Current constraints (name): versionv2.0redshift0.9-1.6
# Current constraints (name): versionv2.0redshift0.9-1.6
# Current constraints (name): versionv2.0redshift0.9-1.6

# %%
mq.ploterr_one_galaxy_param("O VI",toplot,xVar = "rdivR>0",labels = labels)
# Out:
# Current constraints (name): versionv2.0redshift0.9-1.6

# %%
for ion in ["O VI","O V","Ne VIII"]:
    mq.ploterr_one_galaxy_param(ion,toplot,xVar = "rdivR>0",labels = labels)
# Out:
# Current constraints (name): versionv2.0redshift0.9-1.6
# Current constraints (name): versionv2.0redshift0.9-1.6
# Current constraints (name): versionv2.0redshift0.9-1.6

# %%
b = np.empty(3,dtype = 'object')
b[1] = mq
c = np.empty(2,dtype = 'object')
d = np.empty(3,dtype = 'object')

# %%
ions = mq.currentQuasarArray[0].ions

def sort_ions(ions,flat = True):
    from trident import from_roman,to_roman
    def sort_ions_one_element(ions,element):
        from trident import from_roman,to_roman
        nums = [None]*len(ions)
        toreturn = []
        for i in range(len(ions)):
            nums[i] = from_roman(ions[i].split(" ")[1])
        nums.sort()
        for val in nums:
            toreturn.append("%s %s"%(element,to_roman(val)))
        return toreturn
    ions = list(ions)
    ions.sort()
    index = 0
    element = ions[index].split(" ")[0]
    tosort = []
    toreturn = []
    while index < len(ions):
        if ions[index].split(" ")[0] == element:
            tosort.append(ions[index])
            index += 1
        else:
            toreturn.append(sort_ions_one_element(tosort,element))
            element = ions[index].split(" ")[0]
            tosort = []
    toreturn.append(sort_ions_one_element(tosort,element))
    if flat:
        toreturn = [item for sublist in toreturn for item in sublist]
    return toreturn
print ions
print sort_ions(ions)
# Out:
# ['O VI', 'Ne VIII', 'H I', 'C III', 'O IV', 'N III', 'Mg II', 'O V', 'O III', 'N IV', 'Mg X', 'N V', 'S IV', 'O II', 'S III', 'S II', 'S V', 'S VI', 'N II']
# ['C III', 'H I', 'Mg II', 'Mg X', 'N II', 'N III', 'N IV', 'N V', 'Ne VIII', 'O II', 'O III', 'O IV', 'O V', 'O VI', 'S II', 'S III', 'S IV', 'S V', 'S VI']

# %%
np.all(a.size())

# %%
a = np.array([[3]])
a

# %%
np.concatenate(a)

# %%
type(a)

# %%
isinstance(a,np.ndarray)
